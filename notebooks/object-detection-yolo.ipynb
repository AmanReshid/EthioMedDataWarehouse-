# %% [markdown]
# # Object Detection with YOLOv5 and OpenCV
#
# This notebook contains object detection using YOLOv5 on images stored in a directory.
# Contains load a pre-trained YOLOv5 model, perform object detection on each image, display the results, and save the detection data in CSV format.

# %% [markdown]
# ## Import Necessary Libraries

# %%
import sys
sys.path.append('../scripts')  # Add the script folder to the system path

# %%
import object_detection

# %%
from object_detection import *

# %% [markdown]
# ## Loading Pre-trained YOLOv5 Model

# %%
model = load_model()
# Out:
# 2024-10-17 15:34:46,506 - INFO - Loading YOLOv5 model...
# YOLOv5  2024-10-17 Python-3.12.5 torch-2.4.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ### Define Paths

# %%
image_folder = '../data/photos'
save_dir = '../data/detection_results'
num_display_images = 10

# %% [markdown]
# ## Perform Object Detection on Images

# %%
# Process images in the specified folder and run object detection
detection = process_images(model, image_folder)
# Out:
# Processing images:   0%|          | 0/4749 [00:00<?, ?it/s]
# 2024-10-17 15:37:41,054 - INFO - Processed image: @DoctorsET_100.jpg
# Processing images:   0%|          | 1/4749 [00:00<55:34,  1.42it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:41,586 - INFO - Processed image: @DoctorsET_101.jpg
# Processing images:   0%|          | 2/4749 [00:01<47:36,  1.66it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:42,439 - INFO - Processed image: @DoctorsET_102.jpg
# Processing images:   0%|          | 3/4749 [00:02<56:43,  1.39it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:43,153 - INFO - Processed image: @DoctorsET_104.jpg
# Processing images:   0%|          | 4/4749 [00:02<56:35,  1.40it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:44,072 - INFO - Processed image: @DoctorsET_109.jpg
# Processing images:   0%|          | 5/4749 [00:03<1:02:23,  1.27it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:44,813 - INFO - Processed image: @DoctorsET_11.jpg
# Processing images:   0%|          | 6/4749 [00:04<1:01:06,  1.29it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:46,036 - INFO - Processed image: @DoctorsET_110.jpg
# Processing images:   0%|          | 7/4749 [00:05<1:12:41,  1.09it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:47,045 - INFO - Processed image: @DoctorsET_111.jpg
# Processing images:   0%|          | 8/4749 [00:06<1:14:56,  1.05it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:47,808 - INFO - Processed image: @DoctorsET_114.jpg
# Processing images:   0%|          | 9/4749 [00:07<1:10:22,  1.12it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:48,919 - INFO - Processed image: @DoctorsET_115.jpg
# Processing images:   0%|          | 10/4749 [00:08<1:15:41,  1.04it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:49,913 - INFO - Processed image: @DoctorsET_12.jpg
# Processing images:   0%|          | 11/4749 [00:09<1:16:33,  1.03it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:50,693 - INFO - Processed image: @DoctorsET_121.jpg
# Processing images:   0%|          | 12/4749 [00:10<1:11:58,  1.10it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:51,635 - INFO - Processed image: @DoctorsET_124.jpg
# Processing images:   0%|          | 13/4749 [00:11<1:12:42,  1.09it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:52,759 - INFO - Processed image: @DoctorsET_125.jpg
# Processing images:   0%|          | 14/4749 [00:12<1:17:31,  1.02it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:53,940 - INFO - Processed image: @DoctorsET_128.jpg
# Processing images:   0%|          | 15/4749 [00:13<1:22:11,  1.04s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:55,117 - INFO - Processed image: @DoctorsET_129.jpg
# Processing images:   0%|          | 16/4749 [00:14<1:25:24,  1.08s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:56,100 - INFO - Processed image: @DoctorsET_13.jpg
# Processing images:   0%|          | 17/4749 [00:15<1:23:02,  1.05s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:57,207 - INFO - Processed image: @DoctorsET_130.jpg
# Processing images:   0%|          | 18/4749 [00:16<1:24:20,  1.07s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:58,033 - INFO - Processed image: @DoctorsET_131.jpg
# Processing images:   0%|          | 19/4749 [00:17<1:18:30,  1.00it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:37:59,171 - INFO - Processed image: @DoctorsET_133.jpg
# Processing images:   0%|          | 20/4749 [00:18<1:21:50,  1.04s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:00,417 - INFO - Processed image: @DoctorsET_135.jpg
# Processing images:   0%|          | 21/4749 [00:20<1:26:45,  1.10s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:01,325 - INFO - Processed image: @DoctorsET_136.jpg
# Processing images:   0%|          | 22/4749 [00:20<1:22:08,  1.04s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:02,910 - INFO - Processed image: @DoctorsET_137.jpg
# Processing images:   0%|          | 23/4749 [00:22<1:34:59,  1.21s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:04,121 - INFO - Processed image: @DoctorsET_139.jpg
# Processing images:   1%|          | 24/4749 [00:23<1:35:04,  1.21s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:05,028 - INFO - Processed image: @DoctorsET_14.jpg
# Processing images:   1%|          | 25/4749 [00:24<1:27:57,  1.12s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:06,525 - INFO - Processed image: @DoctorsET_140.jpg
# Processing images:   1%|          | 26/4749 [00:26<1:36:55,  1.23s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:07,379 - INFO - Processed image: @DoctorsET_141.jpg
# Processing images:   1%|          | 27/4749 [00:27<1:27:58,  1.12s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:08,155 - INFO - Processed image: @DoctorsET_142.jpg
# Processing images:   1%|          | 28/4749 [00:27<1:19:56,  1.02s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:09,074 - INFO - Processed image: @DoctorsET_146.jpg
# Processing images:   1%|          | 29/4749 [00:28<1:17:35,  1.01it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:10,225 - INFO - Processed image: @DoctorsET_147.jpg
# Processing images:   1%|          | 30/4749 [00:29<1:21:27,  1.04s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:11,140 - INFO - Processed image: @DoctorsET_151.jpg
# Processing images:   1%|          | 31/4749 [00:30<1:18:35,  1.00it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:12,464 - INFO - Processed image: @DoctorsET_152.jpg
# Processing images:   1%|          | 32/4749 [00:32<1:26:13,  1.10s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:13,776 - INFO - Processed image: @DoctorsET_159.jpg
# Processing images:   1%|          | 33/4749 [00:33<1:31:17,  1.16s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:14,335 - INFO - Processed image: @DoctorsET_16.jpg
# Processing images:   1%|          | 34/4749 [00:33<1:17:02,  1.02it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:15,699 - INFO - Processed image: @DoctorsET_164.jpg
# Processing images:   1%|          | 35/4749 [00:35<1:26:05,  1.10s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:16,782 - INFO - Processed image: @DoctorsET_166.jpg
# Processing images:   1%|          | 36/4749 [00:36<1:25:45,  1.09s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:17,992 - INFO - Processed image: @DoctorsET_167.jpg
# Processing images:   1%|          | 37/4749 [00:37<1:28:30,  1.13s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:19,202 - INFO - Processed image: @DoctorsET_173.jpg
# Processing images:   1%|          | 38/4749 [00:38<1:30:29,  1.15s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:20,196 - INFO - Processed image: @DoctorsET_175.jpg
# Processing images:   1%|          | 39/4749 [00:39<1:26:42,  1.10s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:21,289 - INFO - Processed image: @DoctorsET_176.jpg
# Processing images:   1%|          | 40/4749 [00:40<1:26:24,  1.10s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:22,547 - INFO - Processed image: @DoctorsET_177.jpg
# Processing images:   1%|          | 41/4749 [00:42<1:30:07,  1.15s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:23,641 - INFO - Processed image: @DoctorsET_181.jpg
# Processing images:   1%|          | 42/4749 [00:43<1:28:48,  1.13s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:25,180 - INFO - Processed image: @DoctorsET_183.jpg
# Processing images:   1%|          | 43/4749 [00:44<1:38:21,  1.25s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:26,246 - INFO - Processed image: @DoctorsET_184.jpg
# Processing images:   1%|          | 44/4749 [00:45<1:33:54,  1.20s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:27,546 - INFO - Processed image: @DoctorsET_189.jpg
# Processing images:   1%|          | 45/4749 [00:47<1:36:19,  1.23s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:29,060 - INFO - Processed image: @DoctorsET_190.jpg
# Processing images:   1%|          | 46/4749 [00:48<1:43:02,  1.31s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:30,595 - INFO - Processed image: @DoctorsET_194.jpg
# Processing images:   1%|          | 47/4749 [00:50<1:48:08,  1.38s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:31,544 - INFO - Processed image: @DoctorsET_196.jpg
# Processing images:   1%|          | 48/4749 [00:51<1:38:01,  1.25s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:32,456 - INFO - Processed image: @DoctorsET_20.jpg
# Processing images:   1%|          | 49/4749 [00:52<1:30:02,  1.15s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:33,636 - INFO - Processed image: @DoctorsET_201.jpg
# Processing images:   1%|          | 50/4749 [00:53<1:30:43,  1.16s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:35,220 - INFO - Processed image: @DoctorsET_203.jpg
# Processing images:   1%|          | 51/4749 [00:54<1:40:41,  1.29s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:36,326 - INFO - Processed image: @DoctorsET_210.jpg
# Processing images:   1%|          | 52/4749 [00:55<1:36:25,  1.23s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:37,098 - INFO - Processed image: @DoctorsET_212.jpg
# Processing images:   1%|          | 53/4749 [00:56<1:25:39,  1.09s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:38,018 - INFO - Processed image: @DoctorsET_213.jpg
# Processing images:   1%|          | 54/4749 [00:57<1:21:33,  1.04s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:39,040 - INFO - Processed image: @DoctorsET_215.jpg
# Processing images:   1%|          | 55/4749 [00:58<1:21:02,  1.04s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:39,687 - INFO - Processed image: @DoctorsET_216.jpg
# Processing images:   1%|          | 56/4749 [00:59<1:11:50,  1.09it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:40,308 - INFO - Processed image: @DoctorsET_220.jpg
# Processing images:   1%|          | 57/4749 [00:59<1:04:51,  1.21it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:41,356 - INFO - Processed image: @DoctorsET_221.jpg
# Processing images:   1%|          | 58/4749 [01:01<1:10:01,  1.12it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:42,358 - INFO - Processed image: @DoctorsET_224.jpg
# Processing images:   1%|          | 59/4749 [01:02<1:12:31,  1.08it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:43,609 - INFO - Processed image: @DoctorsET_229.jpg
# Processing images:   1%|▏         | 60/4749 [01:03<1:20:03,  1.02s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:44,903 - INFO - Processed image: @DoctorsET_230.jpg
# Processing images:   1%|▏         | 61/4749 [01:04<1:26:21,  1.11s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:45,896 - INFO - Processed image: @DoctorsET_231.jpg
# Processing images:   1%|▏         | 62/4749 [01:05<1:23:42,  1.07s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:47,119 - INFO - Processed image: @DoctorsET_233.jpg
# Processing images:   1%|▏         | 63/4749 [01:06<1:27:12,  1.12s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:48,499 - INFO - Processed image: @DoctorsET_236.jpg
# Processing images:   1%|▏         | 64/4749 [01:08<1:33:23,  1.20s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:49,683 - INFO - Processed image: @DoctorsET_237.jpg
# Processing images:   1%|▏         | 65/4749 [01:09<1:33:04,  1.19s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38:50,715 - INFO - Processed image: @DoctorsET_238.jpg
# Processing images:   1%|▏         | 66/4749 [01:10<1:29:17,  1.14s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:38
C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:48,967 - INFO - Processed image: @EAHCI_1036.jpg
# Processing images:   9%|▉         | 433/4749 [07:08<1:05:53,  1.09it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:49,686 - INFO - Processed image: @EAHCI_1037.jpg
# Processing images:   9%|▉         | 434/4749 [07:09<1:01:39,  1.17it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:50,373 - INFO - Processed image: @EAHCI_1038.jpg
# Processing images:   9%|▉         | 435/4749 [07:10<57:58,  1.24it/s]  C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:51,572 - INFO - Processed image: @EAHCI_1039.jpg
# Processing images:   9%|▉         | 436/4749 [07:11<1:06:25,  1.08it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:52,875 - INFO - Processed image: @EAHCI_1040.jpg
# Processing images:   9%|▉         | 437/4749 [07:12<1:14:34,  1.04s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:54,010 - INFO - Processed image: @EAHCI_1042.jpg
# Processing images:   9%|▉         | 438/4749 [07:13<1:16:40,  1.07s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:54,722 - INFO - Processed image: @EAHCI_1043.jpg
# Processing images:   9%|▉         | 439/4749 [07:14<1:08:59,  1.04it/s]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:55,988 - INFO - Processed image: @EAHCI_1044.jpg
# Processing images:   9%|▉         | 440/4749 [07:15<1:15:34,  1.05s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:57,419 - INFO - Processed image: @EAHCI_1045.jpg
# Processing images:   9%|▉         | 441/4749 [07:17<1:23:41,  1.17s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:58,508 - INFO - Processed image: @EAHCI_1046.jpg
# Processing images:   9%|▉         | 442/4749 [07:18<1:22:01,  1.14s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:44:59,884 - INFO - Processed image: @EAHCI_1047.jpg
# Processing images:   9%|▉         | 443/4749 [07:19<1:27:02,  1.21s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:45:01,213 - INFO - Processed image: @EAHCI_1048.jpg
# Processing images:   9%|▉         | 444/4749 [07:20<1:29:30,  1.25s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:45:02,329 - INFO - Processed image: @EAHCI_1049.jpg
# Processing images:   9%|▉         | 445/4749 [07:21<1:26:39,  1.21s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:45:03,310 - INFO - Processed image: @EAHCI_1050.jpg
# Processing images:   9%|▉         | 446/4749 [07:22<1:21:45,  1.14s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2024-10-17 15:45:04,610 - INFO - Processed image: @EAHCI_1052.jpg
# Processing images:   9%|▉         | 447/4749 [07:24<1:25:10,  1.19s/it]C:\Users\a/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing images:   9%|▉         | 447/4749 [07:24<1:11:18,  1.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Process images in the specified folder and run object detection
# ----> 2 detection = process_images(model, image_folder)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\notebooks\../scripts\object_detection.py:43, in process_images(model, image_folder)
#      40     continue
#      42 # Run object detection
# ---> 43 results = model(img)
#      45 # Store the results
#      46 detection_results.append({
#      47     'image_name': img_name,
#      48     'image': img,
#      49     'results': results
#      50 })
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:895, in AutoShape.forward(self, ims, size, augment, profile)
#     892 with amp.autocast(autocast):
#     893     # Inference
#     894     with dt[1]:
# --> 895         y = self.model(x, augment=augment)  # forward
#     897     # Post-process
#     898     with dt[2]:
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:688, in DetectMultiBackend.forward(self, im, augment, visualize)
#     685     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     687 if self.pt:  # PyTorch
# --> 688     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     689 elif self.jit:  # TorchScript
#     690     y = self.model(im)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\yolo.py:270, in DetectionModel.forward(self, x, augment, profile, visualize)
#     268 if augment:
#     269     return self._forward_augment(x)  # augmented inference, None
# --> 270 return self._forward_once(x, profile, visualize)
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\yolo.py:169, in BaseModel._forward_once(self, x, profile, visualize)
#     167 if profile:
#     168     self._profile_one_layer(m, x, dt)
# --> 169 x = m(x)  # run
#     170 y.append(x if m.i in self.save else None)  # save output
#     171 if visualize:
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:91, in Conv.forward_fuse(self, x)
#      89 def forward_fuse(self, x):
#      90     """Applies a fused convolution and activation function to the input tensor `x`."""
# ---> 91     return self.act(self.conv(x))
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\a\Documents\GitHub\EthioMedDataWarehouse-\venv\Lib\site-packages\torch\nn\modules\conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# Loop through the images in the folder and run object detection
for img_name in os.listdir(image_folder):
    img_path = os.path.join(image_folder, img_name)

    # Read the image using OpenCV
    img = cv2.imread(img_path)

    # Run object detection
    results = model(img)

    # Show the results
    results.show()  # Show detected objects on the image
    results.save(save_dir='../data/detection_results/detection_result')  # Save detection results to a directory

# %% [markdown]
# ## Process and Save Detection Results
# Extract bounding boxes, class labels, and confidence scores from detection results and save them as CSV files.

# %%
for img_name in os.listdir(image_folder):
    img_path = os.path.join(image_folder, img_name)

    # Run object detection
    results = model(img_path)

    # Convert detection results to a pandas DataFrame
    detections = results.pandas().xyxy[0]  # Extracting data into a pandas DataFrame

    # Display detections for each image
    print(f"Detections for {img_name}:")
    print(detections[['name', 'confidence', 'xmin', 'ymin', 'xmax', 'ymax']])

    # Save detection results as CSV files in the 'detection_results' directory
    output_csv_path = f'../data/detection_results/detection_result{img_name}_detections.csv'
    detections[['name', 'confidence', 'xmin', 'ymin', 'xmax', 'ymax']].to_csv(output_csv_path, index=False)
